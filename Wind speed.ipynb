# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('wind_dataset.csv')
df.head(10)
# Out:
#          DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G
# 0  1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0
# 1  1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1
# 2  1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5
# 3  1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2
# 4  1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5
# 5  1961-01-06  10.67    0   0.0    0.0    6.5    0.0    1.2     -2.0
# 6  1961-01-07   9.17    0   1.9    0.0    9.2    1.0   -2.4     -7.1
# 7  1961-01-08  14.29    0   0.0    0.0    6.6    0.0    3.1      0.0
# 8  1961-01-09   8.04    0   8.3    0.0    6.8    0.0    2.4     -0.8
# 9  1961-01-10  11.42    0   0.0    0.0    6.5    0.0    3.0      0.5

# %%
df.shape
# Out:
# (6574, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     6574 non-null   object
#  1   WIND     6574 non-null   float64
#  2   IND      6574 non-null   int64
#  3   RAIN     6574 non-null   float64
#  4   IND.1    6513 non-null   float64
#  5   T.MAX    5953 non-null   float64
#  6   IND.2    6513 non-null   float64
#  7   T.MIN    5900 non-null   float64
#  8   T.MIN.G  6214 non-null   float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 462.4+ KB

# %%
round(df.describe() , 3)
# Out:
#            WIND       IND      RAIN     IND.1     T.MAX     IND.2     T.MIN  \
# count  6574.000  6574.000  6574.000  6513.000  5953.000  6513.000  5900.000
# mean      9.797     0.392     1.885     0.356    13.339     0.464     6.412
# std       4.977     1.179     4.031     1.129     4.891     1.178     4.637
# min       0.000     0.000     0.000     0.000    -0.100     0.000   -11.500
# 25%       6.000     0.000     0.000     0.000     9.600     0.000     3.000
# 50%       9.210     0.000     0.200     0.000    13.300     0.000     6.500
# 75%      12.960     0.000     2.000     0.000    17.200     0.000    10.000
# max      30.370     4.000    67.000     4.000    26.800     4.000    18.000
#
#         T.MIN.G
# count  6214.000
# mean      2.737
# std       5.569
# min     -14.400
# 25%      -1.000
# 50%       3.000
# 75%       7.000
# max      15.800

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# DATE         0
# WIND         0
# IND          0
# RAIN         0
# IND.1       61
# T.MAX      621
# IND.2       61
# T.MIN      674
# T.MIN.G    360
# dtype: int64

# %%
colu = ["IND.1","T.MAX" ,"IND.2" ,"T.MIN" ,"T.MIN.G" ]
for i in colu:
    print(i)
    print(df[i].mode())
# Out:
# IND.1
# 0    0.0
# dtype: float64
# T.MAX
# 0    10.0
# dtype: float64
# IND.2
# 0    0.0
# dtype: float64
# T.MIN
# 0    9.0
# dtype: float64
# T.MIN.G
# 0    5.0
# dtype: float64

# %%
FilterInd1 = 0.0
FilterTmax = 10.0
FilterInd =0.0
FilterTMIN = 9.0
FilterTMIN_g = 5.0
df["IND.1"].fillna(FilterInd1 , inplace = True)
df["T.MAX"].fillna(FilterTmax , inplace = True)
df["IND.2"].fillna(FilterInd , inplace = True)
df["T.MIN"].fillna(FilterTMIN , inplace = True)
df["T.MIN.G"].fillna(FilterTMIN_g , inplace = True)

# %%
df.isnull().sum()
# Out:
# DATE       0
# WIND       0
# IND        0
# RAIN       0
# IND.1      0
# T.MAX      0
# IND.2      0
# T.MIN      0
# T.MIN.G    0
# dtype: int64

# %%
df['DATE'] =pd.to_datetime(df['DATE'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6574 entries, 0 to 6573
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     6574 non-null   datetime64[ns]
#  1   WIND     6574 non-null   float64
#  2   IND      6574 non-null   int64
#  3   RAIN     6574 non-null   float64
#  4   IND.1    6574 non-null   float64
#  5   T.MAX    6574 non-null   float64
#  6   IND.2    6574 non-null   float64
#  7   T.MIN    6574 non-null   float64
#  8   T.MIN.G  6574 non-null   float64
# dtypes: datetime64[ns](1), float64(7), int64(1)
# memory usage: 462.4 KB

# %%
df["Year"] = df['DATE'].dt.year
df["month"] = df['DATE'].dt.month
df["day"] = df['DATE'].dt.day

# %%
df[:50]
# Out:
#          DATE   WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G  Year  \
# 0  1961-01-01  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0  1961
# 1  1961-01-02  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1  1961
# 2  1961-01-03  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5  1961
# 3  1961-01-04   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2  1961
# 4  1961-01-05  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5  1961
# 5  1961-01-06  10.67    0   0.0    0.0    6.5    0.0    1.2     -2.0  1961
# 6  1961-01-07   9.17    0   1.9    0.0    9.2    1.0   -2.4     -7.1  1961
# 7  1961-01-08  14.29    0   0.0    0.0    6.6    0.0    3.1      0.0  1961
# 8  1961-01-09   8.04    0   8.3    0.0    6.8    0.0    2.4     -0.8  1961
# 9  1961-01-10  11.42    0   0.0    0.0    6.5    0.0    3.0      0.5  1961
# 10 1961-01-11   7.54    0   0.5    0.0   10.0    1.0   -3.1     -7.7  1961
# 11 1961-01-12  15.54    0   6.0    0.0   12.2    1.0   -3.3      5.0  1961
# 12 1961-01-13   4.63    0   0.0    0.0   13.1    0.0    5.5      3.3  1961
# 13 1961-01-14   3.08    0   0.0    0.0    5.6    1.0   -3.2     -6.1  1961
# 14 1961-01-15   2.50    0   0.0    0.0    4.4    1.0   -5.0     -8.3  1961
# 15 1961-01-16   9.25    0   0.0    0.0    4.6    1.0   -4.2     -8.3  1961
# 16 1961-01-17  13.42    0   2.0    0.0    9.3    0.0    3.2     -2.7  1961
# 17 1961-01-18  17.83    0   8.4    0.0   10.1    0.0    4.3      5.1  1961
# 18 1961-01-19   3.71    0   0.9    0.0    6.6    0.0    1.6     -2.0  1961
# 19 1961-01-20   3.17    0  21.5    0.0    9.3    1.0   -0.6     -5.4  1961
# 20 1961-01-21   8.04    0   0.2    0.0   10.1    0.0    1.6      0.4  1961
# 24      1   25
# 25      1   26
# 26      1   27
# 27      1   28
# 28      1   29
# 29      1   30
# 30      1   31
# 31      2    1
# 32      2    2
# 33      2    3
# 34      2    4
# 35      2    5
# 36      2    6
# 37      2    7
# 38      2    8
# 39      2    9
# 40      2   10
# 41      2   11
# 42      2   12
# 43      2   13
# 44      2   14
# 45      2   15
# 46      2   16
# 47      2   17
# 48      2   18
# 49      2   19

# %%
month = df["month"]
wind  = df['WIND']
plt.xlabel('Month')
plt.ylabel('Wind Speed')
plt.scatter(month , wind)
plt.show()

# %%
plt.xlabel("T.max")
plt.ylabel("wind")
plt.scatter(df['T.MAX'],wind)
plt.show()

# %%
for i in df.columns:
    plt.xlabel(i)
    plt.ylabel("Wind")
    plt.scatter(df[i] , df["WIND"] ,color ="c")
    plt.show()

# %%
sns.boxplot(x=df['WIND'])
# Out:
# <AxesSubplot:xlabel='WIND'>

# %%
for i in np.where(df["WIND"]>=23):
    df.drop(i,inplace = True)

# %%
df.drop("Year" ,axis =1 ,inplace =True)
df.drop("day" ,axis =1 ,inplace =True)
df.drop("DATE" ,axis =1 ,inplace =True)

# %%
df.head()
# Out:
#     WIND  IND  RAIN  IND.1  T.MAX  IND.2  T.MIN  T.MIN.G  month
# 0  13.67    0   0.2    0.0    9.5    0.0    3.7     -1.0      1
# 1  11.50    0   5.1    0.0    7.2    0.0    4.2      1.1      1
# 2  11.25    0   0.4    0.0    5.5    0.0    0.5     -0.5      1
# 3   8.63    0   0.2    0.0    5.6    0.0    0.4     -3.2      1
# 4  11.92    0  10.4    0.0    7.2    1.0   -1.5     -7.5      1

# %%
X = df.drop('WIND',axis =1)
y = df["WIND"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,random_state=0 ,shuffle=False)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
reg =LinearRegression()
reg.fit(X_train,y_train)
predict = reg.predict(X_test)
print('MAE:', metrics.mean_absolute_error(y_test, predict))
print('MSE:', metrics.mean_squared_error(y_test, predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predict)))
# Out:
# MAE: 3.5112093216577454
# MSE: 19.30003103461627
# RMSE: 4.393180059434882

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics
tree = DecisionTreeRegressor()
tree.fit(X_train,y_train)
predictTree = tree.predict(X_test)
print('MSE' ,metrics.mean_absolute_error(y_test, predict))
print('MSE:', metrics.mean_squared_error(y_test, predict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predict)))
# Out:
# MSE 3.5112093216577454
# MSE: 19.30003103461627
# RMSE: 4.393180059434882

# %%
x_input =pd.DataFrame(np.array([[0,10.4,0.0,7.2,1.0,-1.5,-7.5,1]]))  
reg.predict(x_input)
# Out:
# array([10.31190115])

# %%
x_input =pd.DataFrame(np.array([[0,10.4,0.0,7.2,1.0,-1.5,-7.5,1]]))  
tree.predict(x_input)
# Out:
# array([11.92])

# %%
importance = tree.feature_importances_
# summarize feature 
for i,v in enumerate(importance):
    print(f'Feature: {i}, Score: {round(v,5)}' )
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.01724
# Feature: 1, Score: 0.19254
# Feature: 2, Score: 0.00796
# Feature: 3, Score: 0.24311
# Feature: 4, Score: 0.00729
# Feature: 5, Score: 0.17731
# Feature: 6, Score: 0.24818
# Feature: 7, Score: 0.10637
